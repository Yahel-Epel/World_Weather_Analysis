# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | daxian
# City not found. Skipping...
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | la palma
# Processing Record 8 of Set 1 | coruripe
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | coromandel
# Processing Record 11 of Set 1 | lumby
# Processing Record 12 of Set 1 | vao
# Processing Record 13 of Set 1 | souillac
# Processing Record 14 of Set 1 | la brea
# Processing Record 15 of Set 1 | port elizabeth
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | te anau
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | vostok
# Processing Record 20 of Set 1 | aljezur
# Processing Record 21 of Set 1 | cherskiy
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | hambantota
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | hasaki
# Processing Record 26 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | tibati
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | fort nelson
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | ampanihy
# Processing Record 37 of Set 1 | fortuna
# Processing Record 38 of Set 1 | bathsheba
# Processing Record 39 of Set 1 | lavrentiya
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | tura
# Processing Record 43 of Set 1 | victoria point
# Processing Record 44 of Set 1 | salalah
# Processing Record 45 of Set 1 | manono
# Processing Record 46 of Set 1 | along
# Processing Record 47 of Set 1 | haines junction
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | martaban
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | puerto ayacucho
# Processing Record 4 of Set 2 | hamilton
# Processing Record 5 of Set 2 | kondinskoye
# Processing Record 6 of Set 2 | manyana
# Processing Record 7 of Set 2 | beira
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | piranhas
# Processing Record 11 of Set 2 | narsaq
# Processing Record 12 of Set 2 | manzhouli
# Processing Record 13 of Set 2 | yar-sale
# Processing Record 14 of Set 2 | upernavik
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | chickasha
# Processing Record 17 of Set 2 | svetlogorsk
# Processing Record 18 of Set 2 | geraldton
# Processing Record 19 of Set 2 | rafaela
# Processing Record 20 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 2 | isangel
# Processing Record 22 of Set 2 | vestmannaeyjar
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | kyren
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | pisco
# Processing Record 29 of Set 2 | nemuro
# Processing Record 30 of Set 2 | ilulissat
# Processing Record 31 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 2 | ponta do sol
# Processing Record 33 of Set 2 | cobija
# Processing Record 34 of Set 2 | port lincoln
# Processing Record 35 of Set 2 | malindi
# Processing Record 36 of Set 2 | tuktoyaktuk
# Processing Record 37 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | talnakh
# Processing Record 40 of Set 2 | emerald
# Processing Record 41 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 2 | cayenne
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | jaisalmer
# Processing Record 45 of Set 2 | moirang
# Processing Record 46 of Set 2 | matagami
# Processing Record 47 of Set 2 | taoudenni
# Processing Record 48 of Set 2 | hami
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | albany
# Processing Record 1 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 3 | gannan
# Processing Record 3 of Set 3 | krasnaya gorbatka
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | saint george
# Processing Record 6 of Set 3 | chapais
# Processing Record 7 of Set 3 | chuy
# Processing Record 8 of Set 3 | malakal
# Processing Record 9 of Set 3 | barrow
# Processing Record 10 of Set 3 | neuquen
# Processing Record 11 of Set 3 | pevek
# Processing Record 12 of Set 3 | cockburn town
# Processing Record 13 of Set 3 | la tuque
# Processing Record 14 of Set 3 | boden
# Processing Record 15 of Set 3 | flinders
# Processing Record 16 of Set 3 | selfoss
# Processing Record 17 of Set 3 | viedma
# Processing Record 18 of Set 3 | camacha
# Processing Record 19 of Set 3 | sungaipenuh
# Processing Record 20 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 3 | san matias
# Processing Record 22 of Set 3 | porto novo
# Processing Record 23 of Set 3 | lerwick
# Processing Record 24 of Set 3 | assiniboia
# Processing Record 25 of Set 3 | iralaya
# Processing Record 26 of Set 3 | axim
# Processing Record 27 of Set 3 | constitucion
# Processing Record 28 of Set 3 | mar del plata
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | pathein
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | bardsir
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | calatayud
# Processing Record 35 of Set 3 | aripuana
# Processing Record 36 of Set 3 | san ramon
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | puerto colombia
# Processing Record 39 of Set 3 | nchelenge
# Processing Record 40 of Set 3 | airai
# Processing Record 41 of Set 3 | caravelas
# Processing Record 42 of Set 3 | guerrero negro
# Processing Record 43 of Set 3 | alwar
# Processing Record 44 of Set 3 | marsa matruh
# Processing Record 45 of Set 3 | puerto ayora
# Processing Record 46 of Set 3 | alta floresta
# Processing Record 47 of Set 3 | comarapa
# Processing Record 48 of Set 3 | cehegin
# Processing Record 49 of Set 3 | dunedin
# Processing Record 50 of Set 3 | searcy
# Processing Record 1 of Set 4 | klaksvik
# Processing Record 2 of Set 4 | florida
# Processing Record 3 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 4 | mundo nuevo
# Processing Record 5 of Set 4 | bacalar
# Processing Record 6 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 4 | chalmette
# Processing Record 8 of Set 4 | marrakesh
# Processing Record 9 of Set 4 | lata
# Processing Record 10 of Set 4 | dicabisagan
# Processing Record 11 of Set 4 | gladstone
# Processing Record 12 of Set 4 | maragogi
# Processing Record 13 of Set 4 | bilibino
# Processing Record 14 of Set 4 | dukat
# Processing Record 15 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 4 | biak
# Processing Record 17 of Set 4 | alamor
# Processing Record 18 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 4 | adrar
# Processing Record 20 of Set 4 | alice springs
# Processing Record 21 of Set 4 | inhambane
# Processing Record 22 of Set 4 | winona
# Processing Record 23 of Set 4 | bara
# Processing Record 24 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 4 | balkhash
# Processing Record 26 of Set 4 | kpandae
# Processing Record 27 of Set 4 | kaitangata
# Processing Record 28 of Set 4 | kodiak
# Processing Record 29 of Set 4 | sao joao da barra
# Processing Record 30 of Set 4 | san cristobal
# Processing Record 31 of Set 4 | marawi
# Processing Record 32 of Set 4 | salinopolis
# Processing Record 33 of Set 4 | faanui
# Processing Record 34 of Set 4 | meulaboh
# Processing Record 35 of Set 4 | cape town
# Processing Record 36 of Set 4 | vardo
# Processing Record 37 of Set 4 | norman wells
# Processing Record 38 of Set 4 | tayshet
# Processing Record 39 of Set 4 | mount isa
# Processing Record 40 of Set 4 | springfield
# Processing Record 41 of Set 4 | guaranda
# Processing Record 42 of Set 4 | medicine hat
# Processing Record 43 of Set 4 | luderitz
# Processing Record 44 of Set 4 | korla
# Processing Record 45 of Set 4 | eureka
# Processing Record 46 of Set 4 | san rafael
# Processing Record 47 of Set 4 | annau
# Processing Record 48 of Set 4 | beringovskiy
# Processing Record 49 of Set 4 | trojanovice
# Processing Record 50 of Set 4 | zhigalovo
# Processing Record 1 of Set 5 | sur
# Processing Record 2 of Set 5 | yellowknife
# Processing Record 3 of Set 5 | merrill
# Processing Record 4 of Set 5 | soyo
# Processing Record 5 of Set 5 | broken hill
# Processing Record 6 of Set 5 | labuhan
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | mezen
# Processing Record 9 of Set 5 | lazaro cardenas
# Processing Record 10 of Set 5 | isiro
# Processing Record 11 of Set 5 | cayeli
# Processing Record 12 of Set 5 | georgetown
# Processing Record 13 of Set 5 | catuday
# Processing Record 14 of Set 5 | maniitsoq
# Processing Record 15 of Set 5 | belomorsk
# Processing Record 16 of Set 5 | vila velha
# Processing Record 17 of Set 5 | santo antonio do ica
# Processing Record 18 of Set 5 | houma
# Processing Record 19 of Set 5 | honiara
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | magadan
# Processing Record 22 of Set 5 | cap malheureux
# Processing Record 23 of Set 5 | bambous virieux
# Processing Record 24 of Set 5 | freetown
# Processing Record 25 of Set 5 | lagoa
# Processing Record 26 of Set 5 | baiyin
# Processing Record 27 of Set 5 | pedernales
# Processing Record 28 of Set 5 | raudeberg
# Processing Record 29 of Set 5 | alekseyevskaya
# Processing Record 30 of Set 5 | lepe
# Processing Record 31 of Set 5 | monywa
# Processing Record 32 of Set 5 | nerchinskiy zavod
# Processing Record 33 of Set 5 | fare
# Processing Record 34 of Set 5 | shingu
# Processing Record 35 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 5 | namibe
# Processing Record 37 of Set 5 | saint anthony
# Processing Record 38 of Set 5 | ocampo
# Processing Record 39 of Set 5 | naron
# Processing Record 40 of Set 5 | ruidoso
# Processing Record 41 of Set 5 | poya
# Processing Record 42 of Set 5 | yuyao
# Processing Record 43 of Set 5 | hobart
# Processing Record 44 of Set 5 | almendralejo
# Processing Record 45 of Set 5 | ilheus
# Processing Record 46 of Set 5 | sinor
# Processing Record 47 of Set 5 | provideniya
# Processing Record 48 of Set 5 | victoria
# Processing Record 49 of Set 5 | flora
# Processing Record 50 of Set 5 | padang
# Processing Record 1 of Set 6 | batemans bay
# Processing Record 2 of Set 6 | sao felix do xingu
# Processing Record 3 of Set 6 | maceio
# Processing Record 4 of Set 6 | burica
# City not found. Skipping...
# Processing Record 5 of Set 6 | olavarria
# Processing Record 6 of Set 6 | najran
# Processing Record 7 of Set 6 | rocha
# Processing Record 8 of Set 6 | vila franca do campo
# Processing Record 9 of Set 6 | puri
# Processing Record 10 of Set 6 | bubaque
# Processing Record 11 of Set 6 | carnarvon
# Processing Record 12 of Set 6 | east london
# Processing Record 13 of Set 6 | walvis bay
# Processing Record 14 of Set 6 | taganak
# Processing Record 15 of Set 6 | west bend
# Processing Record 16 of Set 6 | kasongo-lunda
# Processing Record 17 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 6 | nuevo progreso
# Processing Record 19 of Set 6 | menongue
# Processing Record 20 of Set 6 | finschhafen
# Processing Record 21 of Set 6 | asau
# Processing Record 22 of Set 6 | lompoc
# Processing Record 23 of Set 6 | tevriz
# Processing Record 24 of Set 6 | severo-kurilsk
# Processing Record 25 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 26 of Set 6 | niimi
# Processing Record 27 of Set 6 | yusva
# City not found. Skipping...
# Processing Record 28 of Set 6 | price
# Processing Record 29 of Set 6 | miraflores
# Processing Record 30 of Set 6 | banjar
# Processing Record 31 of Set 6 | kupang
# Processing Record 32 of Set 6 | kudahuvadhoo
# Processing Record 33 of Set 6 | brindisi
# Processing Record 34 of Set 6 | el prat de llobregat
# Processing Record 35 of Set 6 | kavieng
# Processing Record 36 of Set 6 | shenjiamen
# Processing Record 37 of Set 6 | fiche
# Processing Record 38 of Set 6 | novichikha
# Processing Record 39 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 6 | dingle
# Processing Record 42 of Set 6 | mafeteng
# Processing Record 43 of Set 6 | san joaquin
# Processing Record 44 of Set 6 | touros
# Processing Record 45 of Set 6 | pacific grove
# Processing Record 46 of Set 6 | alakurtti
# Processing Record 47 of Set 6 | kampot
# Processing Record 48 of Set 6 | acarau
# Processing Record 49 of Set 6 | yulara
# Processing Record 50 of Set 6 | nanortalik
# Processing Record 1 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 7 | marsh harbour
# Processing Record 3 of Set 7 | majengo
# Processing Record 4 of Set 7 | komsomolskiy
# Processing Record 5 of Set 7 | port-cartier
# Processing Record 6 of Set 7 | tabialan
# City not found. Skipping...
# Processing Record 7 of Set 7 | hidas
# Processing Record 8 of Set 7 | sohag
# Processing Record 9 of Set 7 | teahupoo
# Processing Record 10 of Set 7 | bonavista
# Processing Record 11 of Set 7 | nome
# Processing Record 12 of Set 7 | giraltovce
# Processing Record 13 of Set 7 | lota
# Processing Record 14 of Set 7 | vanavara
# Processing Record 15 of Set 7 | aitape
# Processing Record 16 of Set 7 | sambava
# Processing Record 17 of Set 7 | kiunga
# Processing Record 18 of Set 7 | vigia
# Processing Record 19 of Set 7 | mayumba
# Processing Record 20 of Set 7 | valdosta
# Processing Record 21 of Set 7 | tall kayf
# Processing Record 22 of Set 7 | puerto escondido
# Processing Record 23 of Set 7 | ust-kuyga
# Processing Record 24 of Set 7 | buin
# Processing Record 25 of Set 7 | christchurch
# Processing Record 26 of Set 7 | kaeo
# Processing Record 27 of Set 7 | taburao
# City not found. Skipping...
# Processing Record 28 of Set 7 | alcala la real
# Processing Record 29 of Set 7 | fenoarivo
# Processing Record 30 of Set 7 | soeng sang
# Processing Record 31 of Set 7 | ginda
# Processing Record 32 of Set 7 | cairns
# Processing Record 33 of Set 7 | iqaluit
# Processing Record 34 of Set 7 | lloydminster
# Processing Record 35 of Set 7 | juneau
# Processing Record 36 of Set 7 | eching
# Processing Record 37 of Set 7 | mahebourg
# Processing Record 38 of Set 7 | sal rei
# Processing Record 39 of Set 7 | cabo san lucas
# Processing Record 40 of Set 7 | santa maria
# Processing Record 41 of Set 7 | khuzhir
# Processing Record 42 of Set 7 | noumea
# Processing Record 43 of Set 7 | saint-joseph
# Processing Record 44 of Set 7 | caruray
# Processing Record 45 of Set 7 | tommot
# Processing Record 46 of Set 7 | manaus
# Processing Record 47 of Set 7 | minas novas
# Processing Record 48 of Set 7 | balkanabat
# Processing Record 49 of Set 7 | monte alegre
# Processing Record 50 of Set 7 | garissa
# Processing Record 1 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 2 of Set 8 | makakilo city
# Processing Record 3 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 4 of Set 8 | charters towers
# Processing Record 5 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 8 | college
# Processing Record 7 of Set 8 | iskateley
# Processing Record 8 of Set 8 | kralendijk
# Processing Record 9 of Set 8 | dossor
# Processing Record 10 of Set 8 | katsuura
# Processing Record 11 of Set 8 | metro
# Processing Record 12 of Set 8 | faya
# Processing Record 13 of Set 8 | antofagasta
# Processing Record 14 of Set 8 | tambacounda
# Processing Record 15 of Set 8 | nyagan
# Processing Record 16 of Set 8 | buluang
# Processing Record 17 of Set 8 | ugoofaaru
# Processing Record 18 of Set 8 | zhanaozen
# Processing Record 19 of Set 8 | laguna
# Processing Record 20 of Set 8 | la paz
# Processing Record 21 of Set 8 | comodoro rivadavia
# Processing Record 22 of Set 8 | petrovsk-zabaykalskiy
# Processing Record 23 of Set 8 | avera
# Processing Record 24 of Set 8 | susanville
# Processing Record 25 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 8 | marfino
# Processing Record 27 of Set 8 | cidreira
# Processing Record 28 of Set 8 | alytus
# Processing Record 29 of Set 8 | sosva
# Processing Record 30 of Set 8 | valparaiso
# Processing Record 31 of Set 8 | aksu
# Processing Record 32 of Set 8 | san andres
# Processing Record 33 of Set 8 | kisangani
# Processing Record 34 of Set 8 | hobyo
# Processing Record 35 of Set 8 | bac can
# City not found. Skipping...
# Processing Record 36 of Set 8 | aklavik
# Processing Record 37 of Set 8 | ishim
# Processing Record 38 of Set 8 | chabahar
# Processing Record 39 of Set 8 | palmer
# Processing Record 40 of Set 8 | gravdal
# Processing Record 41 of Set 8 | dunda
# Processing Record 42 of Set 8 | opuwo
# Processing Record 43 of Set 8 | nuuk
# Processing Record 44 of Set 8 | yandoon
# City not found. Skipping...
# Processing Record 45 of Set 8 | biltine
# Processing Record 46 of Set 8 | yerbogachen
# Processing Record 47 of Set 8 | maxixe
# Processing Record 48 of Set 8 | auki
# Processing Record 49 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 8 | katobu
# Processing Record 1 of Set 9 | calnali
# Processing Record 2 of Set 9 | daru
# Processing Record 3 of Set 9 | pontes e lacerda
# Processing Record 4 of Set 9 | skjervoy
# Processing Record 5 of Set 9 | ceuasul-de campie
# City not found. Skipping...
# Processing Record 6 of Set 9 | engenheiro beltrao
# Processing Record 7 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 9 | port moresby
# Processing Record 9 of Set 9 | ulagan
# Processing Record 10 of Set 9 | kuloy
# Processing Record 11 of Set 9 | jubbal
# Processing Record 12 of Set 9 | iisalmi
# Processing Record 13 of Set 9 | saldanha
# Processing Record 14 of Set 9 | tekirdag
# Processing Record 15 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 9 | ulaanbaatar
# Processing Record 17 of Set 9 | nouadhibou
# Processing Record 18 of Set 9 | buchen
# Processing Record 19 of Set 9 | porto velho
# Processing Record 20 of Set 9 | sangar
# Processing Record 21 of Set 9 | richards bay
# Processing Record 22 of Set 9 | trinidad
# Processing Record 23 of Set 9 | mahabad
# Processing Record 24 of Set 9 | verkhoyansk
# Processing Record 25 of Set 9 | eau claire
# Processing Record 26 of Set 9 | sol-iletsk
# Processing Record 27 of Set 9 | chokwe
# Processing Record 28 of Set 9 | mae sai
# Processing Record 29 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 9 | carballo
# Processing Record 31 of Set 9 | rawson
# Processing Record 32 of Set 9 | morondava
# Processing Record 33 of Set 9 | foam lake
# Processing Record 34 of Set 9 | teseney
# Processing Record 35 of Set 9 | stephenville
# Processing Record 36 of Set 9 | xuchang
# Processing Record 37 of Set 9 | miramar
# Processing Record 38 of Set 9 | kysyl-syr
# Processing Record 39 of Set 9 | akot
# Processing Record 40 of Set 9 | arawa
# Processing Record 41 of Set 9 | saint-augustin
# Processing Record 42 of Set 9 | ostrovnoy
# Processing Record 43 of Set 9 | fort frances
# Processing Record 44 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 45 of Set 9 | clyde river
# Processing Record 46 of Set 9 | yanam
# Processing Record 47 of Set 9 | huautla
# Processing Record 48 of Set 9 | ketchikan
# Processing Record 49 of Set 9 | seoul
# Processing Record 50 of Set 9 | dikson
# Processing Record 1 of Set 10 | bengkulu
# Processing Record 2 of Set 10 | port hardy
# Processing Record 3 of Set 10 | requena
# Processing Record 4 of Set 10 | calama
# Processing Record 5 of Set 10 | swan hill
# Processing Record 6 of Set 10 | port-de-bouc
# Processing Record 7 of Set 10 | paamiut
# Processing Record 8 of Set 10 | la ronge
# Processing Record 9 of Set 10 | khorixas
# Processing Record 10 of Set 10 | husavik
# Processing Record 11 of Set 10 | linjiang
# Processing Record 12 of Set 10 | botou
# Processing Record 13 of Set 10 | envira
# Processing Record 14 of Set 10 | pyatnitskoye
# Processing Record 15 of Set 10 | merke
# Processing Record 16 of Set 10 | ust-koksa
# Processing Record 17 of Set 10 | ust-kulom
# Processing Record 18 of Set 10 | skofja loka
# Processing Record 19 of Set 10 | mehamn
# Processing Record 20 of Set 10 | dunmore town
# Processing Record 21 of Set 10 | blackwater
# Processing Record 22 of Set 10 | benin
# Processing Record 23 of Set 10 | hillsboro
# Processing Record 24 of Set 10 | kerema
# Processing Record 25 of Set 10 | sargatskoye
# Processing Record 26 of Set 10 | alugan
# Processing Record 27 of Set 10 | kurumkan
# Processing Record 28 of Set 10 | tieling
# Processing Record 29 of Set 10 | laslea
# Processing Record 30 of Set 10 | ferme-neuve
# Processing Record 31 of Set 10 | mogadishu
# Processing Record 32 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 10 | barra do garcas
# Processing Record 35 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 10 | zile
# Processing Record 37 of Set 10 | zyryanka
# Processing Record 38 of Set 10 | carahue
# Processing Record 39 of Set 10 | morgan hill
# Processing Record 40 of Set 10 | sadao
# Processing Record 41 of Set 10 | sondershausen
# Processing Record 42 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 10 | sakakah
# Processing Record 44 of Set 10 | mormugao
# Processing Record 45 of Set 10 | totma
# Processing Record 46 of Set 10 | oranjemund
# Processing Record 47 of Set 10 | kamenka
# Processing Record 48 of Set 10 | svetlyy
# Processing Record 49 of Set 10 | imbituba
# Processing Record 50 of Set 10 | bogale
# Processing Record 1 of Set 11 | grindavik
# Processing Record 2 of Set 11 | mahon
# Processing Record 3 of Set 11 | luena
# Processing Record 4 of Set 11 | coihaique
# Processing Record 5 of Set 11 | manokwari
# Processing Record 6 of Set 11 | takoradi
# Processing Record 7 of Set 11 | kamphaeng phet
# Processing Record 8 of Set 11 | poum
# Processing Record 9 of Set 11 | boyuibe
# Processing Record 10 of Set 11 | pyay
# Processing Record 11 of Set 11 | mporokoso
# Processing Record 12 of Set 11 | turbat
# Processing Record 13 of Set 11 | neiafu
# Processing Record 14 of Set 11 | kruisfontein
# Processing Record 15 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 11 | sahuaripa
# Processing Record 17 of Set 11 | raga
# Processing Record 18 of Set 11 | zimovniki
# Processing Record 19 of Set 11 | manakara
# Processing Record 20 of Set 11 | harper
# Processing Record 21 of Set 11 | asyut
# Processing Record 22 of Set 11 | torbay
# Processing Record 23 of Set 11 | zenica
# Processing Record 24 of Set 11 | kushiro
# Processing Record 25 of Set 11 | goulburn
# Processing Record 26 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 11 | scarborough
# Processing Record 28 of Set 11 | prince rupert
# Processing Record 29 of Set 11 | biala podlaska
# Processing Record 30 of Set 11 | batagay-alyta
# Processing Record 31 of Set 11 | kashi
# Processing Record 32 of Set 11 | napier
# Processing Record 33 of Set 11 | san patricio
# Processing Record 34 of Set 11 | yarada
# Processing Record 35 of Set 11 | borogontsy
# Processing Record 36 of Set 11 | jobner
# Processing Record 37 of Set 11 | canutama
# Processing Record 38 of Set 11 | araouane
# Processing Record 39 of Set 11 | uzumlu
# City not found. Skipping...
# Processing Record 40 of Set 11 | sobue
# Processing Record 41 of Set 11 | samaipata
# Processing Record 42 of Set 11 | hutchinson
# Processing Record 43 of Set 11 | juba
# Processing Record 44 of Set 11 | hovd
# Processing Record 45 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 46 of Set 11 | huron
# Processing Record 47 of Set 11 | lichtenau
# Processing Record 48 of Set 11 | anadyr
# Processing Record 49 of Set 11 | hailin
# Processing Record 50 of Set 11 | itarema
# Processing Record 1 of Set 12 | kampil
# Processing Record 2 of Set 12 | emmett
# Processing Record 3 of Set 12 | jose bonifacio
# Processing Record 4 of Set 12 | fairbanks
# Processing Record 5 of Set 12 | sakaiminato
# Processing Record 6 of Set 12 | kenai
# Processing Record 7 of Set 12 | aasiaat
# Processing Record 8 of Set 12 | elizabeth city
# Processing Record 9 of Set 12 | suihua
# Processing Record 10 of Set 12 | necochea
# Processing Record 11 of Set 12 | minab
# Processing Record 12 of Set 12 | buchanan
# Processing Record 13 of Set 12 | berlevag
# Processing Record 14 of Set 12 | lagos
# Processing Record 15 of Set 12 | odweyne
# Processing Record 16 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 12 | krasnofarfornyy
# Processing Record 18 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 12 | gat
# Processing Record 20 of Set 12 | deori
# Processing Record 21 of Set 12 | ormara
# Processing Record 22 of Set 12 | borazjan
# Processing Record 23 of Set 12 | suba
# Processing Record 24 of Set 12 | bolshaya murta
# City not found. Skipping...
# Processing Record 25 of Set 12 | ancud
# Processing Record 26 of Set 12 | northam
# Processing Record 27 of Set 12 | colesberg
# Processing Record 28 of Set 12 | san pedro del pinatar
# Processing Record 29 of Set 12 | progreso
# Processing Record 30 of Set 12 | baghdad
# Processing Record 31 of Set 12 | raichur
# Processing Record 32 of Set 12 | kamaishi
# Processing Record 33 of Set 12 | narasannapeta
# Processing Record 34 of Set 12 | flin flon
# Processing Record 35 of Set 12 | sinnamary
# Processing Record 36 of Set 12 | ayr
# Processing Record 37 of Set 12 | zvenigovo
# Processing Record 38 of Set 12 | denpasar
# Processing Record 39 of Set 12 | karpogory
# Processing Record 40 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 12 | humberto de campos
# Processing Record 42 of Set 12 | pafos
# Processing Record 43 of Set 12 | boguchany
# Processing Record 44 of Set 12 | santo tomas
# Processing Record 45 of Set 12 | bangassou
# Processing Record 46 of Set 12 | buala
# Processing Record 47 of Set 12 | ucluelet
# Processing Record 48 of Set 12 | temir
# Processing Record 49 of Set 12 | tevaitoa
# Processing Record 50 of Set 12 | broome
# Processing Record 1 of Set 13 | namatanai
# Processing Record 2 of Set 13 | port hedland
# Processing Record 3 of Set 13 | rosarito
# Processing Record 4 of Set 13 | den helder
# Processing Record 5 of Set 13 | san policarpo
# Processing Record 6 of Set 13 | yuci
# Processing Record 7 of Set 13 | puerto baquerizo moreno
# Processing Record 8 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 9 of Set 13 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 10 of Set 13 | lorengau
# Processing Record 11 of Set 13 | sungairaya
# Processing Record 12 of Set 13 | minsk
# Processing Record 13 of Set 13 | san juan
# Processing Record 14 of Set 13 | lagoa vermelha
# Processing Record 15 of Set 13 | ippy
# Processing Record 16 of Set 13 | ranong
# Processing Record 17 of Set 13 | teya
# Processing Record 18 of Set 13 | campbell river
# Processing Record 19 of Set 13 | canyon
# Processing Record 20 of Set 13 | hakkari
# Processing Record 21 of Set 13 | emborion
# Processing Record 22 of Set 13 | belogorsk
# Processing Record 23 of Set 13 | tsaratanana
# Processing Record 24 of Set 13 | miandrivazo
# Processing Record 25 of Set 13 | san quintin
# Processing Record 26 of Set 13 | am timan
# Processing Record 27 of Set 13 | ohangaron
# Processing Record 28 of Set 13 | jian
# Processing Record 29 of Set 13 | ngunguru
# Processing Record 30 of Set 13 | bonfim
# Processing Record 31 of Set 13 | salta
# Processing Record 32 of Set 13 | hornepayne
# Processing Record 33 of Set 13 | akdagmadeni
# Processing Record 34 of Set 13 | majene
# Processing Record 35 of Set 13 | batagay
# Processing Record 36 of Set 13 | pangnirtung
# Processing Record 37 of Set 13 | amos
# Processing Record 38 of Set 13 | lakselv
# Processing Record 39 of Set 13 | barcelona
# Processing Record 40 of Set 13 | carupano
# Processing Record 41 of Set 13 | omboue
# Processing Record 42 of Set 13 | union
# Processing Record 43 of Set 13 | nara
# Processing Record 44 of Set 13 | mitsamiouli
# Processing Record 45 of Set 13 | adre
# Processing Record 46 of Set 13 | shcholkine
# City not found. Skipping...
# Processing Record 47 of Set 13 | celestun
# Processing Record 48 of Set 13 | huilong
# Processing Record 49 of Set 13 | puerto narino
# Processing Record 50 of Set 13 | george
# Processing Record 1 of Set 14 | okha
# Processing Record 2 of Set 14 | evensk
# Processing Record 3 of Set 14 | kahului
# Processing Record 4 of Set 14 | kolondieba
# Processing Record 5 of Set 14 | winnemucca
# Processing Record 6 of Set 14 | hohhot
# Processing Record 7 of Set 14 | sorland
# Processing Record 8 of Set 14 | pokrovsk
# Processing Record 9 of Set 14 | alofi
# Processing Record 10 of Set 14 | kayanga
# Processing Record 11 of Set 14 | brigantine
# Processing Record 12 of Set 14 | kyra
# Processing Record 13 of Set 14 | barahona
# Processing Record 14 of Set 14 | ferrol
# Processing Record 15 of Set 14 | paita
# Processing Record 16 of Set 14 | moranbah
# Processing Record 17 of Set 14 | kiama
# Processing Record 18 of Set 14 | ara
# Processing Record 19 of Set 14 | lodja
# Processing Record 20 of Set 14 | russkaya polyana
# Processing Record 21 of Set 14 | vallenar
# Processing Record 22 of Set 14 | davidson
# Processing Record 23 of Set 14 | uvat
# Processing Record 24 of Set 14 | port-gentil
# Processing Record 25 of Set 14 | codrington
# Processing Record 26 of Set 14 | hofn
# Processing Record 27 of Set 14 | ozernovskiy
# Processing Record 28 of Set 14 | dymer
# Processing Record 29 of Set 14 | karratha
# Processing Record 30 of Set 14 | surt
# Processing Record 31 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 14 | quatre cocos
# Processing Record 33 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 34 of Set 14 | inuvik
# Processing Record 35 of Set 14 | hervey bay
# Processing Record 36 of Set 14 | san isidro
# Processing Record 37 of Set 14 | aginskoye
# Processing Record 38 of Set 14 | gari
# Processing Record 39 of Set 14 | ohaba
# Processing Record 40 of Set 14 | lesnoye
# Processing Record 41 of Set 14 | chupa
# Processing Record 42 of Set 14 | sfantu gheorghe
# Processing Record 43 of Set 14 | smithers
# Processing Record 44 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 45 of Set 14 | rognan
# Processing Record 46 of Set 14 | latung
# Processing Record 47 of Set 14 | selkirk
# Processing Record 48 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 49 of Set 14 | louis trichardt
# Processing Record 50 of Set 14 | mount gambier
# Processing Record 1 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 2 of Set 15 | tabou
# Processing Record 3 of Set 15 | saint-georges
# Processing Record 4 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 15 | bonito
# Processing Record 6 of Set 15 | mackay
# Processing Record 7 of Set 15 | rawah
# Processing Record 8 of Set 15 | iringa
# Processing Record 9 of Set 15 | samus
# Processing Record 10 of Set 15 | chimbote
# Processing Record 11 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 12 of Set 15 | safford
# Processing Record 13 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 14 of Set 15 | warrnambool
# Processing Record 15 of Set 15 | salekhard
# Processing Record 16 of Set 15 | jizan
# Processing Record 17 of Set 15 | sukhoy log
# Processing Record 18 of Set 15 | ixtapa
# Processing Record 19 of Set 15 | coquimbo
# Processing Record 20 of Set 15 | esmeraldas
# Processing Record 21 of Set 15 | piacabucu
# Processing Record 22 of Set 15 | srivardhan
# Processing Record 23 of Set 15 | pierre
# Processing Record 24 of Set 15 | jardim
# Processing Record 25 of Set 15 | pingzhuang
# Processing Record 26 of Set 15 | kamogawa
# Processing Record 27 of Set 15 | tuatapere
# Processing Record 28 of Set 15 | diamantino
# Processing Record 29 of Set 15 | puerto del rosario
# Processing Record 30 of Set 15 | praia
# Processing Record 31 of Set 15 | sadri
# Processing Record 32 of Set 15 | ballina
# Processing Record 33 of Set 15 | fort morgan
# Processing Record 34 of Set 15 | lixourion
# Processing Record 35 of Set 15 | basco
# Processing Record 36 of Set 15 | shalakusha
# Processing Record 37 of Set 15 | anakapalle
# Processing Record 38 of Set 15 | kita
# Processing Record 39 of Set 15 | elko
# Processing Record 40 of Set 15 | saint-francois
# Processing Record 41 of Set 15 | altamira
# Processing Record 42 of Set 15 | orlik
# Processing Record 43 of Set 15 | bosobolo
# Processing Record 44 of Set 15 | plainfield
# Processing Record 45 of Set 15 | almaznyy
# Processing Record 46 of Set 15 | hualmay
# Processing Record 47 of Set 15 | port arthur
# Processing Record 48 of Set 15 | la solana
# Processing Record 49 of Set 15 | grand gaube
# Processing Record 50 of Set 15 | bowen
# Processing Record 1 of Set 16 | coahuayana
# Processing Record 2 of Set 16 | hay river
# Processing Record 3 of Set 16 | santa cruz
# Processing Record 4 of Set 16 | half moon bay
# Processing Record 5 of Set 16 | pandamatenga
# Processing Record 6 of Set 16 | katangli
# Processing Record 7 of Set 16 | naze
# Processing Record 8 of Set 16 | tambo
# Processing Record 9 of Set 16 | san luis
# Processing Record 10 of Set 16 | borovoy
# Processing Record 11 of Set 16 | dharchula
# Processing Record 12 of Set 16 | kavarna
# Processing Record 13 of Set 16 | muzhi
# Processing Record 14 of Set 16 | tambopata
# Processing Record 15 of Set 16 | beyneu
# Processing Record 16 of Set 16 | praia da vitoria
# Processing Record 17 of Set 16 | bud
# Processing Record 18 of Set 16 | ploemeur
# Processing Record 19 of Set 16 | marmaris
# Processing Record 20 of Set 16 | inderborskiy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0      Castro -24.7911  -50.0119       broken clouds     72.68        76
# 1     Rikitea -23.1203 -134.9692       broken clouds     78.57        72
# 2    Khatanga  71.9667  102.5000     overcast clouds      3.67        80
# 3    Tasiilaq  65.6145  -37.6368     overcast clouds     11.48        80
# 4       Vaini -21.2000 -175.2000       broken clouds     79.88        82
# 5    La Palma  33.8464 -118.0467    scattered clouds     83.50        26
# 6    Coruripe -10.1256  -36.1756           clear sky     82.65        68
# 7        Hilo  19.7297 -155.0900    scattered clouds     76.24        71
# 8  Coromandel -18.4733  -47.2003     overcast clouds     68.47        94
# 9       Lumby  50.2498 -118.9690     overcast clouds     43.66        85
#
#    Cloudiness  Wind Speed Country
# 0          74        4.81      BR
# 1          54       10.65      PF
# 2         100       17.74      RU
# 3         100        8.63      GL
# 4          67       24.11      TO
# 5          45        1.99      US
# 6           0       13.29      BR
# 7          40        6.91      US
# 8         100        3.69      BR
# 9         100        5.75      CA

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Castro      BR -24.7911  -50.0119     72.68        76          74
# 1     Rikitea      PF -23.1203 -134.9692     78.57        72          54
# 2    Khatanga      RU  71.9667  102.5000      3.67        80         100
# 3    Tasiilaq      GL  65.6145  -37.6368     11.48        80         100
# 4       Vaini      TO -21.2000 -175.2000     79.88        82          67
# 5    La Palma      US  33.8464 -118.0467     83.50        26          45
# 6    Coruripe      BR -10.1256  -36.1756     82.65        68           0
# 7        Hilo      US  19.7297 -155.0900     76.24        71          40
# 8  Coromandel      BR -18.4733  -47.2003     68.47        94         100
# 9       Lumby      CA  50.2498 -118.9690     43.66        85         100
#
#    Wind Speed Current Description
# 0        4.81       broken clouds
# 1       10.65       broken clouds
# 2       17.74     overcast clouds
# 3        8.63     overcast clouds
# 4       24.11       broken clouds
# 5        1.99    scattered clouds
# 6       13.29           clear sky
# 7        6.91    scattered clouds
# 8        3.69     overcast clouds
# 9        5.75     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
